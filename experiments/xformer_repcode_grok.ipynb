# %%
# reload magic
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# add the parent directory to the path
import sys
import os
import numpy as np
import torch
import random

import logging

sys.path.append('..')
from mldec.pipelines.seq2seq import build_model, train_model
from mldec.pipelines.dataloader import Sampler
from mldec.pipelines.logger import get_logger
from mldec.pipelines.utils import gpu_init_pytorch

# %%
log_folder = 'logs'
model_folder = 'models'
result_folder = './out/'

data_path = 'data/'
__file__ = os.path.abspath('')
data_path = os.path.abspath(os.path.join(os.path.dirname( __file__ ), data_path))
print(data_path)
def load_data(config, logger, add_sos_eos=False, preload_device=None):	
	'''
		Loads the data from the datapath in torch dataset form. 
		
		I believe this needs to be in the main run file, to account for how data will 
		be passed around during tuning runs.
		
		Note that the test loader is "unweighted", and performance will need to be manually 
		    weighted by the underlying distribution.

		Args:
			config (dict) : configuration/args
			logger (logger) : logger object for logging

		Returns:
			dataloader(s) for train, val, and test. 
	'''
	if config.mode == 'train' or config.mode == 'tune':
		logger.debug('Loading Training Data...')
		train_path = os.path.join(data_path, config.experiment_name, config.dataset)
		# val_path = os.path.join(data_path, config.experiment_name, config.dataset, 'val.pkl')
		test_path = os.path.join(data_path, config.experiment_name, config.dataset)

		'''Load Datasets'''
		train_loader = Sampler(train_path, config.batch_size, mode='train', add_sos_eos=add_sos_eos, preload_device=preload_device)
		# test dataset is designed to contain all examples
		test_loader = Sampler(test_path, 2 ** config.n, mode='test', add_sos_eos=add_sos_eos, preload_device=preload_device)
		msg = 'Training and Validation Data Loaded:\nTrain Size: {}\nTest Size: {}. Output shape: {}'.format(train_loader.n_data, test_loader.n_data, train_loader.output_shape)
		logger.info(msg)
		
		return train_loader, test_loader
	else:
		logger.critical('Invalid Mode Specified')
		raise Exception('{} is not a valid mode'.format(config.mode))
# Out:
# c:\Users\peter\Desktop\projects\quantum_error_correction\decoding-nonpauli-errors\data

# %%
# Initialize logger
run_name = "test"
log_file = "test.log"
logger = get_logger(run_name, log_file_path=None, logging_level=logging.DEBUG)

# %%
class DummyArgs:
    """Dummy class to hold arguments"""
    def __init__(self):
        self.mode = 'train'
        self.seed = 1235
        self.gpu = 0 # TODO
        self.checkpoint = None # TODO
        self.experiment_name = 'repetition_code_v1'

        self.n = 8
        # self.dataset = f'n{self.n}_N10000_p101_p2007'
        self.dataset = f'grok_n8_N102_p101_p2007'
        self.batch_size = 8

        self.heads = 4
        self.depth = 4
        self.d_model = 16
        self.d_ffn = 8
        # no dropout for noiseless data
        self.dropout = 0.0

        self.epochs = 1000
        self.opt = 'adam'
        self.lr = 5e-5
        self.max_grad_norm = 0


# better for jupyter noteboook:
# logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)

config = DummyArgs()
# parser = build_parser()
# config = parser.parse_args()
is_train = (config.mode == 'train')
is_tune = (config.mode == 'tune')

# Seeds should be consistent
np.random.seed(config.seed)
random.seed(config.seed)
torch.manual_seed(config.seed)

# Set device
if config.gpu is not None:
    device = gpu_init_pytorch(config.gpu)
else:
    device = torch.device('cpu')
print("device", device)
# Out:
# device cuda:0

# %%
# Load the data
train_loader, test_loader = load_data(config, logger, add_sos_eos=True, preload_device=device)
# Out:
# 12-12 17 | 646936226.py : load_data() ::	 Loading Training Data...
# 12-12 17 | 646936226.py : load_data() ::	 Loading Training Data...
# 12-12 17 | 646936226.py : load_data() ::	 Training and Validation Data Loaded:
# Train Size: 102
# Test Size: 256. Output shape: (102, 10)
# 12-12 17 | 646936226.py : load_data() ::	 Training and Validation Data Loaded:
# Train Size: 102
# Test Size: 256. Output shape: (102, 10)

# %%
# Initialize model
model = build_model(config, device, logger)

# X, Y = test_loader.get_batch(0)
# model.evaluator(X, Y, weights=test_loader.weights)
# Out:
# 12-12 17 | seq2seq.py : __init__() ::	 Initalizing Model...
# 12-12 17 | seq2seq.py : __init__() ::	 Initalizing Model...
# 12-12 17 | seq2seq.py : __init__() ::	 Initalizing Optimizer and Criterion...
# 12-12 17 | seq2seq.py : __init__() ::	 Initalizing Optimizer and Criterion...
# 12-12 17 | seq2seq.py : build_model() ::	 Model has 16196 trainable parameters
# 12-12 17 | seq2seq.py : build_model() ::	 Model has 16196 trainable parameters

# %%
logger.info('Starting Training Procedure')
train_model(model, train_loader, test_loader, device, config, logger)
# Out:
# 12-12 17 | 3923464849.py : <module>() ::	 Starting Training Procedure
# 12-12 17 | 3923464849.py : <module>() ::	 Starting Training Procedure
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 1 completed...
# Time Taken: 0 mins and 0.5483837127685547 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 1 completed...
# Time Taken: 0 mins and 0.5483837127685547 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (inf --> -0.000000).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (inf --> -0.000000).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 1 | Train Loss: 1.2295284271240234 | Train Acc: 0.0 | Val Acc: 0.0 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 1 | Train Loss: 1.2295284271240234 | Train Acc: 0.0 | Val Acc: 0.0 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 2 completed...
# Time Taken: 0 mins and 0.449845552444458 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 2 completed...
# Time Taken: 0 mins and 0.449845552444458 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.000000 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.000000 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 2 | Train Loss: 1.093077201109666 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 2 | Train Loss: 1.093077201109666 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 3 completed...
# Time Taken: 0 mins and 0.45432257652282715 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 3 completed...
# Time Taken: 0 mins and 0.45432257652282715 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 3 | Train Loss: 1.0245637801977305 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 3 | Train Loss: 1.0245637801977305 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 4 completed...
# Time Taken: 0 mins and 0.4439101219177246 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 4 completed...
# Time Taken: 0 mins and 0.4439101219177246 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 4 | Train Loss: 0.9829515402133648 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 4 | Train Loss: 0.9829515402133648 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 5 completed...
# Time Taken: 0 mins and 0.49958133697509766 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 5 completed...
# Time Taken: 0 mins and 0.49958133697509766 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 5 | Train Loss: 0.9504291002566998 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 5 | Train Loss: 0.9504291002566998 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 6 completed...
# Time Taken: 0 mins and 0.4524199962615967 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 6 completed...
# Time Taken: 0 mins and 0.4524199962615967 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 6 | Train Loss: 0.9266528395506052 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 6 | Train Loss: 0.9266528395506052 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 7 completed...
# Time Taken: 0 mins and 0.47022032737731934 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 7 completed...
# Time Taken: 0 mins and 0.47022032737731934 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 7 | Train Loss: 0.9093915545023404 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 7 | Train Loss: 0.9093915545023404 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 8 completed...
# Time Taken: 0 mins and 0.47785115242004395 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 8 completed...
# Time Taken: 0 mins and 0.47785115242004395 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 8 | Train Loss: 0.8957201746793894 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 8 | Train Loss: 0.8957201746793894 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 9 completed...
# Time Taken: 0 mins and 0.45429420471191406 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 9 completed...
# Time Taken: 0 mins and 0.45429420471191406 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 9 | Train Loss: 0.8844449474261358 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 9 | Train Loss: 0.8844449474261358 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 10 completed...
# Time Taken: 0 mins and 0.4818532466888428 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 10 completed...
# Time Taken: 0 mins and 0.4818532466888428 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 10 | Train Loss: 0.8750356756723844 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 10 | Train Loss: 0.8750356756723844 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 11 completed...
# Time Taken: 0 mins and 0.4496936798095703 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 11 completed...
# Time Taken: 0 mins and 0.4496936798095703 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 11 | Train Loss: 0.8668571893985455 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 11 | Train Loss: 0.8668571893985455 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 12 completed...
# Time Taken: 0 mins and 0.45026159286499023 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 12 completed...
# Time Taken: 0 mins and 0.45026159286499023 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 12 | Train Loss: 0.8598344417718741 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 12 | Train Loss: 0.8598344417718741 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 13 completed...
# Time Taken: 0 mins and 0.4358837604522705 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 13 completed...
# Time Taken: 0 mins and 0.4358837604522705 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 13 | Train Loss: 0.8538915790044345 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 13 | Train Loss: 0.8538915790044345 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 14 completed...
# Time Taken: 0 mins and 0.46122002601623535 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 14 completed...
# Time Taken: 0 mins and 0.46122002601623535 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 14 | Train Loss: 0.8487924887583806 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 14 | Train Loss: 0.8487924887583806 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 15 completed...
# Time Taken: 0 mins and 0.4637033939361572 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 15 completed...
# Time Taken: 0 mins and 0.4637033939361572 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 15 | Train Loss: 0.8444672272755549 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 15 | Train Loss: 0.8444672272755549 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 16 completed...
# Time Taken: 0 mins and 0.438828706741333 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 16 completed...
# Time Taken: 0 mins and 0.438828706741333 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 16 | Train Loss: 0.8408390879631042 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 16 | Train Loss: 0.8408390879631042 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 17 completed...
# Time Taken: 0 mins and 0.4428222179412842 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 17 completed...
# Time Taken: 0 mins and 0.4428222179412842 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 17 | Train Loss: 0.837701875429887 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 17 | Train Loss: 0.837701875429887 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 18 completed...
# Time Taken: 0 mins and 0.4305438995361328 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 18 completed...
# Time Taken: 0 mins and 0.4305438995361328 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 18 | Train Loss: 0.835042050251594 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 18 | Train Loss: 0.835042050251594 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 19 completed...
# Time Taken: 0 mins and 0.42713189125061035 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 19 completed...
# Time Taken: 0 mins and 0.42713189125061035 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 19 | Train Loss: 0.8326780520952665 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 19 | Train Loss: 0.8326780520952665 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 20 completed...
# Time Taken: 0 mins and 0.42435503005981445 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 20 completed...
# Time Taken: 0 mins and 0.42435503005981445 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 20 | Train Loss: 0.8305501754467304 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 20 | Train Loss: 0.8305501754467304 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 21 completed...
# Time Taken: 0 mins and 0.4334981441497803 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 21 completed...
# Time Taken: 0 mins and 0.4334981441497803 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 21 | Train Loss: 0.8285621450497553 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 21 | Train Loss: 0.8285621450497553 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 22 completed...
# Time Taken: 0 mins and 0.42232704162597656 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 22 completed...
# Time Taken: 0 mins and 0.42232704162597656 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 22 | Train Loss: 0.826537026808812 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 22 | Train Loss: 0.826537026808812 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 23 completed...
# Time Taken: 0 mins and 0.4642026424407959 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 23 completed...
# Time Taken: 0 mins and 0.4642026424407959 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 23 | Train Loss: 0.8246853855940012 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 23 | Train Loss: 0.8246853855940012 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 24 completed...
# Time Taken: 0 mins and 0.44205355644226074 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 24 completed...
# Time Taken: 0 mins and 0.44205355644226074 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 24 | Train Loss: 0.823084125152001 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 24 | Train Loss: 0.823084125152001 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 25 completed...
# Time Taken: 0 mins and 0.4968264102935791 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 25 completed...
# Time Taken: 0 mins and 0.4968264102935791 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 25 | Train Loss: 0.8215149549337534 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 25 | Train Loss: 0.8215149549337534 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 26 completed...
# Time Taken: 0 mins and 0.44144368171691895 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 26 completed...
# Time Taken: 0 mins and 0.44144368171691895 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 26 | Train Loss: 0.819976059290079 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 26 | Train Loss: 0.819976059290079 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 27 completed...
# Time Taken: 0 mins and 0.4521517753601074 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 27 completed...
# Time Taken: 0 mins and 0.4521517753601074 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 27 | Train Loss: 0.8185713703815753 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 27 | Train Loss: 0.8185713703815753 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 28 completed...
# Time Taken: 0 mins and 0.4395883083343506 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 28 completed...
# Time Taken: 0 mins and 0.4395883083343506 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 28 | Train Loss: 0.8172687383798453 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 28 | Train Loss: 0.8172687383798453 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 29 completed...
# Time Taken: 0 mins and 0.44924068450927734 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 29 completed...
# Time Taken: 0 mins and 0.44924068450927734 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 29 | Train Loss: 0.8160246060444758 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 29 | Train Loss: 0.8160246060444758 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 30 completed...
# Time Taken: 0 mins and 0.4498879909515381 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 30 completed...
# Time Taken: 0 mins and 0.4498879909515381 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 30 | Train Loss: 0.8148244023323059 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 30 | Train Loss: 0.8148244023323059 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 31 completed...
# Time Taken: 0 mins and 0.4446859359741211 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 31 completed...
# Time Taken: 0 mins and 0.4446859359741211 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 31 | Train Loss: 0.8136666829769428 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 31 | Train Loss: 0.8136666829769428 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 32 completed...
# Time Taken: 0 mins and 0.47479963302612305 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 32 completed...
# Time Taken: 0 mins and 0.47479963302612305 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 32 | Train Loss: 0.8125363634182856 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 32 | Train Loss: 0.8125363634182856 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 33 completed...
# Time Taken: 0 mins and 0.4425528049468994 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 33 completed...
# Time Taken: 0 mins and 0.4425528049468994 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 33 | Train Loss: 0.8114116329413193 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 33 | Train Loss: 0.8114116329413193 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 34 completed...
# Time Taken: 0 mins and 0.43538689613342285 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 34 completed...
# Time Taken: 0 mins and 0.43538689613342285 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 34 | Train Loss: 0.8102806577315698 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 34 | Train Loss: 0.8102806577315698 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 35 completed...
# Time Taken: 0 mins and 0.41312122344970703 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 35 completed...
# Time Taken: 0 mins and 0.41312122344970703 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 35 | Train Loss: 0.8091246302311237 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 35 | Train Loss: 0.8091246302311237 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 36 completed...
# Time Taken: 0 mins and 0.4095313549041748 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 36 completed...
# Time Taken: 0 mins and 0.4095313549041748 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 36 | Train Loss: 0.8077235451111426 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 36 | Train Loss: 0.8077235451111426 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 37 completed...
# Time Taken: 0 mins and 0.4095325469970703 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 37 completed...
# Time Taken: 0 mins and 0.4095325469970703 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 37 | Train Loss: 0.8064242234596839 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 37 | Train Loss: 0.8064242234596839 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 38 completed...
# Time Taken: 0 mins and 0.40047335624694824 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 38 completed...
# Time Taken: 0 mins and 0.40047335624694824 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 38 | Train Loss: 0.80522987475762 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 38 | Train Loss: 0.80522987475762 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 39 completed...
# Time Taken: 0 mins and 0.4435851573944092 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 39 completed...
# Time Taken: 0 mins and 0.4435851573944092 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 39 | Train Loss: 0.8040033074525686 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 39 | Train Loss: 0.8040033074525686 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 40 completed...
# Time Taken: 0 mins and 0.39779090881347656 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 40 completed...
# Time Taken: 0 mins and 0.39779090881347656 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 40 | Train Loss: 0.8027407572819636 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 40 | Train Loss: 0.8027407572819636 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 41 completed...
# Time Taken: 0 mins and 0.4030635356903076 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 41 completed...
# Time Taken: 0 mins and 0.4030635356903076 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 41 | Train Loss: 0.8014972439179053 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 41 | Train Loss: 0.8014972439179053 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 42 completed...
# Time Taken: 0 mins and 0.4917428493499756 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 42 completed...
# Time Taken: 0 mins and 0.4917428493499756 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 42 | Train Loss: 0.8003417115945083 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 42 | Train Loss: 0.8003417115945083 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 43 completed...
# Time Taken: 0 mins and 0.4638855457305908 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 43 completed...
# Time Taken: 0 mins and 0.4638855457305908 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 43 | Train Loss: 0.7991513288938082 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 43 | Train Loss: 0.7991513288938082 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 44 completed...
# Time Taken: 0 mins and 0.43779468536376953 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 44 completed...
# Time Taken: 0 mins and 0.43779468536376953 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 44 | Train Loss: 0.7978633458797748 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 44 | Train Loss: 0.7978633458797748 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 45 completed...
# Time Taken: 0 mins and 0.5328404903411865 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 45 completed...
# Time Taken: 0 mins and 0.5328404903411865 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 45 | Train Loss: 0.7963482095645025 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 45 | Train Loss: 0.7963482095645025 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 46 completed...
# Time Taken: 0 mins and 0.511751651763916 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 46 completed...
# Time Taken: 0 mins and 0.511751651763916 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 46 | Train Loss: 0.7947654265623826 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 46 | Train Loss: 0.7947654265623826 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 47 completed...
# Time Taken: 0 mins and 0.49523138999938965 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 47 completed...
# Time Taken: 0 mins and 0.49523138999938965 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 47 | Train Loss: 0.7931382197600144 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 47 | Train Loss: 0.7931382197600144 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 48 completed...
# Time Taken: 0 mins and 0.4947509765625 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 48 completed...
# Time Taken: 0 mins and 0.4947509765625 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 48 | Train Loss: 0.7914534211158752 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 48 | Train Loss: 0.7914534211158752 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 49 completed...
# Time Taken: 0 mins and 0.5001115798950195 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 49 completed...
# Time Taken: 0 mins and 0.5001115798950195 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 49 | Train Loss: 0.7895517532642071 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 49 | Train Loss: 0.7895517532642071 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 50 completed...
# Time Taken: 0 mins and 0.48746466636657715 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 50 completed...
# Time Taken: 0 mins and 0.48746466636657715 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 50 | Train Loss: 0.7876125665811392 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 50 | Train Loss: 0.7876125665811392 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 51 completed...
# Time Taken: 0 mins and 0.5489034652709961 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 51 completed...
# Time Taken: 0 mins and 0.5489034652709961 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 51 | Train Loss: 0.7855758116795466 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 51 | Train Loss: 0.7855758116795466 | Train Acc: 0.009615384973585606 | Val Acc: 0.0019171754829585552 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 52 completed...
# Time Taken: 0 mins and 0.43070363998413086 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 52 completed...
# Time Taken: 0 mins and 0.43070363998413086 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : save_checkpoint() ::	 Validation loss decreased (-0.001917 --> -0.001917).  Saving model ...
# ...
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 981 completed...
# Time Taken: 0 mins and 0.5240013599395752 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 981 completed...
# Time Taken: 0 mins and 0.5240013599395752 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 887 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 887 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 981 | Train Loss: 0.0005196215083392767 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 981 | Train Loss: 0.0005196215083392767 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 982 completed...
# Time Taken: 0 mins and 0.43999671936035156 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 982 completed...
# Time Taken: 0 mins and 0.43999671936035156 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 888 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 888 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 982 | Train Loss: 0.0005162795468305165 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 982 | Train Loss: 0.0005162795468305165 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 983 completed...
# Time Taken: 0 mins and 0.392413854598999 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 983 completed...
# Time Taken: 0 mins and 0.392413854598999 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 889 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 889 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 983 | Train Loss: 0.0005129984212824359 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 983 | Train Loss: 0.0005129984212824359 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 984 completed...
# Time Taken: 0 mins and 0.4280862808227539 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 984 completed...
# Time Taken: 0 mins and 0.4280862808227539 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 890 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 890 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 984 | Train Loss: 0.0005095694102167797 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 984 | Train Loss: 0.0005095694102167797 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 985 completed...
# Time Taken: 0 mins and 0.40400147438049316 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 985 completed...
# Time Taken: 0 mins and 0.40400147438049316 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 891 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 891 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 985 | Train Loss: 0.0005061359104449645 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 985 | Train Loss: 0.0005061359104449645 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 986 completed...
# Time Taken: 0 mins and 0.49771690368652344 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 986 completed...
# Time Taken: 0 mins and 0.49771690368652344 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 892 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 892 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 986 | Train Loss: 0.0005028078583284066 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 986 | Train Loss: 0.0005028078583284066 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 987 completed...
# Time Taken: 0 mins and 0.3800022602081299 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 987 completed...
# Time Taken: 0 mins and 0.3800022602081299 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 893 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 893 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 987 | Train Loss: 0.0004995084063221628 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 987 | Train Loss: 0.0004995084063221628 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 988 completed...
# Time Taken: 0 mins and 0.4119994640350342 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 988 completed...
# Time Taken: 0 mins and 0.4119994640350342 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 894 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 894 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 988 | Train Loss: 0.0004961599748080167 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 988 | Train Loss: 0.0004961599748080167 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 989 completed...
# Time Taken: 0 mins and 0.496124267578125 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 989 completed...
# Time Taken: 0 mins and 0.496124267578125 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 895 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 895 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 989 | Train Loss: 0.0004929680569777981 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 989 | Train Loss: 0.0004929680569777981 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 990 completed...
# Time Taken: 0 mins and 0.4159982204437256 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 990 completed...
# Time Taken: 0 mins and 0.4159982204437256 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 896 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 896 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 990 | Train Loss: 0.0004897184396843211 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 990 | Train Loss: 0.0004897184396843211 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 991 completed...
# Time Taken: 0 mins and 0.3999826908111572 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 991 completed...
# Time Taken: 0 mins and 0.3999826908111572 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 897 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 897 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 991 | Train Loss: 0.0004867306807472442 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 991 | Train Loss: 0.0004867306807472442 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 992 completed...
# Time Taken: 0 mins and 0.37924814224243164 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 992 completed...
# Time Taken: 0 mins and 0.37924814224243164 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 898 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 898 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 992 | Train Loss: 0.0004834672436118126 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 992 | Train Loss: 0.0004834672436118126 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 993 completed...
# Time Taken: 0 mins and 0.38686037063598633 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 993 completed...
# Time Taken: 0 mins and 0.38686037063598633 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 899 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 899 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 993 | Train Loss: 0.0004802394877725209 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 993 | Train Loss: 0.0004802394877725209 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 994 completed...
# Time Taken: 0 mins and 0.39600634574890137 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 994 completed...
# Time Taken: 0 mins and 0.39600634574890137 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 900 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 900 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 994 | Train Loss: 0.00047712756070093467 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 994 | Train Loss: 0.00047712756070093467 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 995 completed...
# Time Taken: 0 mins and 0.3840365409851074 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 995 completed...
# Time Taken: 0 mins and 0.3840365409851074 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 901 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 901 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 995 | Train Loss: 0.0004740808060607658 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 995 | Train Loss: 0.0004740808060607658 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 996 completed...
# Time Taken: 0 mins and 0.39202070236206055 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 996 completed...
# Time Taken: 0 mins and 0.39202070236206055 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 902 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 902 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 996 | Train Loss: 0.0004709239493912229 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 996 | Train Loss: 0.0004709239493912229 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 997 completed...
# Time Taken: 0 mins and 0.4499967098236084 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 997 completed...
# Time Taken: 0 mins and 0.4499967098236084 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 903 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 903 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 997 | Train Loss: 0.0004679505095387307 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 997 | Train Loss: 0.0004679505095387307 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 998 completed...
# Time Taken: 0 mins and 0.41217041015625 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 998 completed...
# Time Taken: 0 mins and 0.41217041015625 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 904 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 904 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 998 | Train Loss: 0.00046480206163743365 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 998 | Train Loss: 0.00046480206163743365 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 999 completed...
# Time Taken: 0 mins and 0.38547348976135254 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Training for epoch 999 completed...
# Time Taken: 0 mins and 0.38547348976135254 secs
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | seq2seq.py : train_model() ::	 Starting Validation
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 905 out of 1000
# 12-12 17 | utils.py : __call__() ::	 EarlyStopping counter: 905 out of 1000
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 999 | Train Loss: 0.0004618078506050202 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Epoch: 999 | Train Loss: 0.0004618078506050202 | Train Acc: 0.0 | Val Acc: 9.37890650559714e-12 | LR: 5e-05
# 12-12 17 | seq2seq.py : train_model() ::	 Training Completed for 1000 epochs
# 12-12 17 | seq2seq.py : train_model() ::	 Training Completed for 1000 epochs

# %%
X, Y = test_loader.get_batch(0)
Y_preds = model.predict(X)
for x, y, y_pred in zip(X, Y, Y_preds):
    print(x)
    print(y)
    print(y_pred)
    print()
# Out:
# tensor([0, 0, 0, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 1, 1, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 1, 1, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([0, 1, 1, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 1, 0, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 1, 1, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 1, 1, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 0, 0], device='cuda:0')
#
# tensor([0, 0, 0, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 1, 1, 1, 1], device='cuda:0')
#
# tensor([1, 1, 1, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 1, 1, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 0, 0], device='cuda:0')
#
# tensor([1, 1, 1, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 0, 1, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 0, 1, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 0, 0], device='cuda:0')
#
# tensor([1, 1, 1, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 1, 1, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 1, 1, 1, 1], device='cuda:0')
#
# tensor([1, 1, 1, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 0, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 0, 1, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 0, 0], device='cuda:0')
#
# tensor([0, 1, 1, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 0, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 0, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 0, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 1, 1, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 1, 1, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([1, 1, 0, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 1, 3, 0, 0, 1, 0, 1, 0], device='cuda:0')
#
# tensor([0, 1, 1, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 0, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 0, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 0, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 0, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 1, 1, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 0, 1, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 0, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 1, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 0, 1, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 1, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 0, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 0, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 0, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 0, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 0, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 0, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 1, 0, 0, 0, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 0, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 1, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 0, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 1, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 0, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 0, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 1, 0, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([1, 0, 0, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 0, 1, 1, 1, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 1, 1, 1, 1, 1, 1, 3], device='cuda:0')
#
# tensor([1, 1, 0, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 0, 1, 1, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 1, 1, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 0, 1, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 1, 1, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 0, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 1, 1, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 0, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 1, 1, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 0, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 0, 1, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 1, 0, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 0, 0, 1], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 1, 1, 0, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 1, 3], device='cuda:0')
#
# tensor([0, 0, 0, 0, 0, 0, 0], device='cuda:0')
# tensor([2, 1, 1, 1, 1, 1, 1, 1, 1, 3], device='cuda:0')
# tensor([2, 0, 0, 0, 0, 0, 0, 0, 0, 3], device='cuda:0')

# %%
# clean this shit up.


class DummyArgs:
	"""Dummy for argparser results."""
	def __init__(self):
		self.mode = 'train'
		self.seed = 1234
		self.gpu = None
		
def main():
	'''Read arguments'''

	'''Run Config files/paths'''
	# run_name = config.run_name
	# config.log_path = os.path.join(log_folder, run_name)
	# config.model_path = os.path.join(model_folder, config.dataset, run_name)
	# config_file = os.path.join(config.model_path, 'config.p')
	# log_file = os.path.join(config.log_path, 'log.txt')

	# if config.results:
	# 	config.result_path = os.path.join(result_folder, 'val_results_{}.json'.format(config.dataset))
	
	# if is_train or is_tune:
	# 	create_save_directories(config.log_path, config.model_path, result_folder)
	# else:
	# 	create_save_directories(config.log_path, None, result_folder)

	# logger = get_logger(run_name, log_file, logging.DEBUG)
	# logger.debug('Created Relevant Directories')
	# logger.info('Experiment Name: {}'.format(config.run_name)
    # )
	

	if is_train:
		# checkpoint = get_latest_checkpoint(config.model_path, logger)
		checkpoint = None
		min_val_loss = torch.tensor(float('inf')).item()
		epoch_offset = 0

		if checkpoint:
			ckpt = torch.load(checkpoint, map_location=lambda storage, loc: storage)
			config.lr = ckpt['lr']
			model = build_model(config=config, device=device, logger=logger)
			model.load_state_dict(ckpt['model_state_dict'])
			model.optimizer.load_state_dict(ckpt['optimizer_state_dict'])
		else:
			model = build_model(config=config, device=device, logger=logger)
			

            
		logger.info('Initialized Model')
		
		with open(config_file, 'wb') as f:
			pickle.dump(vars(config), f, protocol=pickle.HIGHEST_PROTOCOL)
		logger.debug('Config File Saved')

		num_params =count_parameters(model)
		logger.info('Number of parameters {}'.format(num_params))
		
		logger.info('Starting Training Procedure')
		train_model(model, train_loader, val_loader, voc, device, config, logger, epoch_offset, min_val_loss)

	elif is_tune:
		# Hyperparameter tuning happens here. I don't use command line inputs for
		# this config because it would be like pulling teeth.
		hyper_config = {
			'lr': tune.choice([1e-4]),
			'd_model': tune.choice([32]),
			'depth': tune.choice([1, 2]),
			'd_ffn': tune.choice([64]),
			'heads':tune.choice([2])
		}

		# The way raytune distributes compute resources is to use all possible resources,
		# then maximize the number of trials such that cpus/gpus per worker below are satisfied.
		# To avoid overutilization, set `max_concurrent_trials`
		# https://docs.ray.io/en/latest/tune/tutorials/tune-resources.html
		hyper_settings = {
			"cpus_per_worker": 0,
			"gpus_per_worker": 1,
			"max_concurrent_trials": 1,
			"epochs": 100,
			"num_samples": 10,
		}

		min_val_loss = torch.tensor(float('inf')).item()
		epoch_offset= 0

		logger.info('Starting Tuning Procedure')

		# Overwriting the config settings with the hyperparameters
		config.tune = True
		for key, value in hyper_config.items():
			setattr(config, key, value)

		tune_model(hyper_settings, hyper_config, train_loader, val_loader, voc, config, logger, epoch_offset, min_val_loss)
